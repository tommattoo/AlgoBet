# %%
import requests
import json

# Define API endpoint and headers
uri = "https://api.football-data.org/v4/matches?dateFrom=2025-03-10&dateTo=2025-03-20"
headers = {"X-Auth-Token": "038a29ae77b040edb4aa9c03a7787346"}  # Replace with your actual API key

# Make the request
response = requests.get(uri, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    data = response.json()
    matches = data.get("matches", [])  # Retrieve 'matches' safely

    if matches:
        print(f"Retrieved {len(matches)} matches:")
        for match in matches:
            print(json.dumps(match, indent=4))  # Pretty print match data
    else:
        print("No matches found in the given date range.")
else:
    print(f"Error: {response.status_code} - {response.text}")  # Show error message
# Out:
# Retrieved 104 matches:
# {
#     "area": {
#         "id": 2114,
#         "name": "Italy",
#         "code": "ITA",
#         "flag": "https://crests.football-data.org/784.svg"
#     },
#     "competition": {
#         "id": 2019,
#         "name": "Serie A",
#         "code": "SA",
#         "type": "LEAGUE",
#         "emblem": "https://crests.football-data.org/SA.png"
#     },
#     "season": {
#         "id": 2310,
#         "startDate": "2024-08-18",
#         "endDate": "2025-05-25",
#         "currentMatchday": 30,
#         "winner": null
#     },
#     "id": 503319,
#     "utcDate": "2025-03-10T19:45:00Z",
#     "status": "FINISHED",
#     "matchday": 28,
#     "stage": "REGULAR_SEASON",
#     "group": null,
#     "lastUpdated": "2025-03-26T00:21:15Z",
#     "homeTeam": {
#         "id": 110,
#         "name": "SS Lazio",
#         "shortName": "Lazio",
#         "tla": "LAZ",
#         "crest": "https://crests.football-data.org/110.png"
#     },
#     "awayTeam": {
# ...
